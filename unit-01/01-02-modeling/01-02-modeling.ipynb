# %% [markdown]
# # Introduction to Mathematical Modeling

# %% [markdown]
# In this video on the 3blue1brown YouTube channel, the author, Grant Sanderson, explores the SIR Model for modeling the spread of disease. Watch the video before answering the following questions.
#
# To view the video, run the cell. I suggest playing it fullscreen (23 min).
#
# There are questions to answer at the end of this notebook based on the video. I suggest reviewing (and maybe printing) the questions before watching the video. Then, as you watch the video, occasionally pause the video and make notes on the various questions. Otherwise, you may forget the details before the end of the video.

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('gxAaO2rsdIs', width=800, height=400)

# %% [markdown]
# ## Question 1

# %% [markdown]
# Sometimes in modeling the spread of disease, R stands for **recovered**.  What does R stand for in Sanderson's model, and how is it defined?

# %% [markdown]
# ## Question 2

# %% [markdown]
# What are some of the questions Sanders investigates with his models?

# %% [markdown]
# ## Question 3

# %% [markdown]
# What are Sanderson's five key takeaways?

# %% [markdown]
# ## Questions 4

# %% [markdown]
# What are some ethical considerations raised by watching this video? Sanderson makes some statements that are ethically related. But you can also expound on ethical ideas not directly mentioned in the video.
